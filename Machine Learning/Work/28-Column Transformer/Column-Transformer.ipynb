# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('covid_toy.csv')
df.sample(5)
# Out:
#     age  gender  fever   cough       city has_covid
# 46   19  Female  101.0    Mild     Mumbai        No
# 30   15    Male  101.0    Mild      Delhi       Yes
# 78   11    Male  100.0    Mild  Bangalore       Yes
# 23   80  Female   98.0    Mild      Delhi       Yes
# 32   34  Female  101.0  Strong      Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.sample()
# Out:
#     age gender  fever cough       city has_covid
# 63   10   Male  100.0  Mild  Bangalore        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 76   80    Male  100.0    Mild  Bangalore
# 39   50  Female  103.0    Mild    Kolkata
# 49   44    Male  104.0    Mild     Mumbai
# 21   73    Male   98.0    Mild  Bangalore
# 83   17  Female  104.0    Mild    Kolkata
# ..  ...     ...    ...     ...        ...
# 40   49  Female  102.0    Mild      Delhi
# 1    27    Male  100.0    Mild      Delhi
# 18   64  Female   98.0    Mild  Bangalore
# 35   82  Female  102.0  Strong  Bangalore
# 44   20    Male  102.0  Strong      Delhi
#
# [80 rows x 5 columns]

# %% [markdown]
# # **Performing column Transformation by 2 method**

# %% [markdown]
# **1.Aam Zindagi**

# %%
# adding simple imputer to fever col
from sklearn.impute import SimpleImputer
si = SimpleImputer()
X_train_fever = si.fit_transform(X_train[['fever']])

# also the test data
X_test_fever = si.fit_transform(X_test[['fever']])
                                 
X_train_fever.shape
# Out:
# (80, 1)

# %%
# Ordinalencoding -> cough
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Mild','Strong']])
X_train_cough = oe.fit_transform(X_train[['cough']])

# also the test data
X_test_cough = oe.fit_transform(X_test[['cough']])

X_train_cough.shape
# Out:
# (80, 1)

# %%
# OneHotEncoding -> gender,city
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first',sparse_output=False)
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])

# also the test data
X_test_gender_city = ohe.fit_transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# (80, 4)

# %%
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values

# also the test data
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values

X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city,X_train_cough),axis=1)
# also the test data
X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city,X_test_cough),axis=1)

X_train_transformed.shape
# Out:
# (80, 7)

# %% [markdown]
# # **Mentos Zindagi**

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1',SimpleImputer,['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['gender','city'])
],remainder='passthrough')

# %%
transformer.fit_transform(X_train).shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 transformer.fit_transform(X_train).shape
#
# File ~\Anaacoda\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\Anaacoda\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\Anaacoda\Lib\site-packages\sklearn\compose\_column_transformer.py:996, in ColumnTransformer.fit_transform(self, X, y, **params)
#     993 else:
#     994     routed_params = self._get_empty_routing()
# --> 996 result = self._call_func_on_transformers(
#     997     X,
#     998     y,
#     999     _fit_transform_one,
#    1000     column_as_labels=False,
#    1001     routed_params=routed_params,
#    1002 )
#    1004 if not result:
#    1005     self._update_fitted_transformers([])
#
# File ~\Anaacoda\Lib\site-packages\sklearn\compose\_column_transformer.py:888, in ColumnTransformer._call_func_on_transformers(self, X, y, func, column_as_labels, routed_params)
#     884         else:  # func is _transform_one
#     885             extra_args = {}
#     886         jobs.append(
#     887             delayed(func)(
# --> 888                 transformer=clone(trans) if not fitted else trans,
#     889                 X=_safe_indexing(X, columns, axis=1),
#     890                 y=y,
#     891                 weight=weight,
#     892                 **extra_args,
#     893                 params=routed_params[name],
#     894             )
#     895         )
#     897     return Parallel(n_jobs=self.n_jobs)(jobs)
#     899 except ValueError as e:
#
# File ~\Anaacoda\Lib\site-packages\sklearn\base.py:95, in clone(estimator, safe)
#      93 if hasattr(estimator, "__sklearn_clone__") and not inspect.isclass(estimator):
#      94     return estimator.__sklearn_clone__()
# ---> 95 return _clone_parametrized(estimator, safe=safe)
#
# File ~\Anaacoda\Lib\site-packages\sklearn\base.py:111, in _clone_parametrized(estimator, safe)
#     109 else:
#     110     if isinstance(estimator, type):
# --> 111         raise TypeError(
#     112             "Cannot clone object. "
#     113             "You should provide an instance of "
#     114             "scikit-learn estimator instead of a class."
#     115         )
#     116     else:
#     117         raise TypeError(
#     118             "Cannot clone object '%s' (type %s): "
#     119             "it does not seem to be a scikit-learn "
#     120             "estimator as it does not implement a "
#     121             "'get_params' method." % (repr(estimator), type(estimator))
#     122         )
#
# TypeError: Cannot clone object. You should provide an instance of scikit-learn estimator instead of a class.
